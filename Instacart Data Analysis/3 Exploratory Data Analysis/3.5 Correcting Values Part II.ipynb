# %% [markdown]
# ## Correcting an Incorrect Value in the Instacart Data
#
# ### Contents
# #### Importing Libraries
# #### Importing Data
# #### Fixing Incorrect Value
# #### Exporting Data

# %% [markdown]
# ### Importing Data

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### Importing Data

# %%
# Define pathway to relevant folder
path = r'/Users/sydneyjohnson/Documents/CF Data Analytics Course/07-2024 Instacart Basket Analysis'

# %%
# Import ords_prods_merged.pkl
df = pd.read_pickle(os.path.join(path, '02 Data','Prepared Data', 'combo_7_25.pkl'))

# %% [markdown]
# ### Fixing Incorrect Value

# %%
# Identify Max value
max_price = df['prices'].max()
print(max_price)
# Out:
# 14900.0

# %%
# Create subset of max value
filtered_df = df[df['prices'] == 14900]

print(filtered_df)
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 1576        912404       17            12                   2
# 1638        603376       17            22                   6
# 16522      3264360      135             2                   2
# 16528       892534      135             3                   0
# 53672       229704      342             8                   1
# ...            ...      ...           ...                 ...
# 32320511   3172853   205650            18                   1
# 32347717   2504315   205818             3                   5
# 32347727   1108388   205818             5                   4
# 32380527   1916142   206049             1                   2
# 32380551    379732   206049             4                   1
#
#           order_hour_placed  days_since_prior_order  product_id  \
# 1576                     14                     5.0       21553
# 1638                     16                     4.0       21553
# 16522                    21                    13.0       21553
# 16528                     8                    12.0       21553
# 53672                    19                    30.0       21553
# ...                     ...                     ...         ...
# 32320511                  9                     7.0       21553
# 32347717                 15                     3.0       21553
# 32347727                  5                     1.0       21553
# 32380527                 17                     NaN       21553
# 32380551                 14                     5.0       21553
#
#           add_to_cart_order  reordered                      product_name  \
# 1576                      5          0  Lowfat 2% Milkfat Cottage Cheese
# 1638                      3          1  Lowfat 2% Milkfat Cottage Cheese
# 16522                     6          0  Lowfat 2% Milkfat Cottage Cheese
# 16528                     3          1  Lowfat 2% Milkfat Cottage Cheese
# 53672                     9          0  Lowfat 2% Milkfat Cottage Cheese
# ...                     ...        ...                               ...
# 32320511                 17          1  Lowfat 2% Milkfat Cottage Cheese
# 32347717                 13          0  Lowfat 2% Milkfat Cottage Cheese
# 32347727                  5          1  Lowfat 2% Milkfat Cottage Cheese
# 32380527                  2          0  Lowfat 2% Milkfat Cottage Cheese
# 32380551                  4          1  Lowfat 2% Milkfat Cottage Cheese
#
#           aisle_id  department_id   prices _merge  max_order  \
# 1576           108             16  14900.0   both         40
# 1638           108             16  14900.0   both         40
# 16522          108             16  14900.0   both          4
# 16528          108             16  14900.0   both          4
# 53672          108             16  14900.0   both         16
# ...            ...            ...      ...    ...        ...
# 32320511       108             16  14900.0   both         25
# 32347717       108             16  14900.0   both         25
# 32347727       108             16  14900.0   both         25
# 32380527       108             16  14900.0   both          5
# 32380551       108             16  14900.0   both          5
#
#               loyalty_flag    avg_price spending_flag  med_days_prior  \
# 1576      Regular customer   108.648299  High Spender             5.0
# 1638      Regular customer   108.648299  High Spender             5.0
# 16522         New customer  1154.792308  High Spender            12.0
# 16528         New customer  1154.792308  High Spender            12.0
# 53672     Regular customer   114.426619  High Spender            23.0
# ...                    ...          ...           ...             ...
# 32320511  Regular customer   351.141618  High Spender             6.0
# 32347717  Regular customer   170.073770  High Spender            13.0
# 32347727  Regular customer   170.073770  High Spender            13.0
# 32380527      New customer   938.031250  High Spender             7.0
# 32380551      New customer   938.031250  High Spender             7.0
#
#                  frequency_flag
# 1576          Frequent customer
# 1638          Frequent customer
# 16522          Regular customer
# 16528          Regular customer
# 53672     Non-frequent customer
# ...                         ...
# 32320511      Frequent customer
# 32347717       Regular customer
# 32347727       Regular customer
# 32380527      Frequent customer
# 32380551      Frequent customer
#
# [4429 rows x 20 columns]

# %%
filtered_df.head()
# Out:
#        order_id  user_id  order_number  orders_day_of_week  order_hour_placed  \
# 1576     912404       17            12                   2                 14
# 1638     603376       17            22                   6                 16
# 16522   3264360      135             2                   2                 21
# 16528    892534      135             3                   0                  8
# 53672    229704      342             8                   1                 19
#
#        days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 1576                      5.0       21553                  5          0
# 1638                      4.0       21553                  3          1
# 16522                    13.0       21553                  6          0
# 16528                    12.0       21553                  3          1
# 53672                    30.0       21553                  9          0
#
#                            product_name  aisle_id  department_id   prices  \
# 1576   Lowfat 2% Milkfat Cottage Cheese       108             16  14900.0
# 1638   Lowfat 2% Milkfat Cottage Cheese       108             16  14900.0
# 16522  Lowfat 2% Milkfat Cottage Cheese       108             16  14900.0
# 16528  Lowfat 2% Milkfat Cottage Cheese       108             16  14900.0
# 53672  Lowfat 2% Milkfat Cottage Cheese       108             16  14900.0
#
#       _merge  max_order      loyalty_flag    avg_price spending_flag  \
# 1576    both         40  Regular customer   108.648299  High Spender
# 1638    both         40  Regular customer   108.648299  High Spender
# 16522   both          4      New customer  1154.792308  High Spender
# 16528   both          4      New customer  1154.792308  High Spender
# 53672   both         16  Regular customer   114.426619  High Spender
#
#        med_days_prior         frequency_flag
# 1576              5.0      Frequent customer
# 1638              5.0      Frequent customer
# 16522            12.0       Regular customer
# 16528            12.0       Regular customer
# 53672            23.0  Non-frequent customer

# %%
filtered_df.tail()
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 32320511   3172853   205650            18                   1
# 32347717   2504315   205818             3                   5
# 32347727   1108388   205818             5                   4
# 32380527   1916142   206049             1                   2
# 32380551    379732   206049             4                   1
#
#           order_hour_placed  days_since_prior_order  product_id  \
# 32320511                  9                     7.0       21553
# 32347717                 15                     3.0       21553
# 32347727                  5                     1.0       21553
# 32380527                 17                     NaN       21553
# 32380551                 14                     5.0       21553
#
#           add_to_cart_order  reordered                      product_name  \
# 32320511                 17          1  Lowfat 2% Milkfat Cottage Cheese
# 32347717                 13          0  Lowfat 2% Milkfat Cottage Cheese
# 32347727                  5          1  Lowfat 2% Milkfat Cottage Cheese
# 32380527                  2          0  Lowfat 2% Milkfat Cottage Cheese
# 32380551                  4          1  Lowfat 2% Milkfat Cottage Cheese
#
#           aisle_id  department_id   prices _merge  max_order  \
# 32320511       108             16  14900.0   both         25
# 32347717       108             16  14900.0   both         25
# 32347727       108             16  14900.0   both         25
# 32380527       108             16  14900.0   both          5
# 32380551       108             16  14900.0   both          5
#
#               loyalty_flag   avg_price spending_flag  med_days_prior  \
# 32320511  Regular customer  351.141618  High Spender             6.0
# 32347717  Regular customer  170.073770  High Spender            13.0
# 32347727  Regular customer  170.073770  High Spender            13.0
# 32380527      New customer  938.031250  High Spender             7.0
# 32380551      New customer  938.031250  High Spender             7.0
#
#              frequency_flag
# 32320511  Frequent customer
# 32347717   Regular customer
# 32347727   Regular customer
# 32380527  Frequent customer
# 32380551  Frequent customer

# %%
# Through research, I found that a gallon of Lowfat 2% Milkfat Cottage Cheese usually costs $4. I will use that value instead of the mean
# Replace 14900 with 4 in the 'prices' column
df['prices'].replace(14900.0, 4, inplace=True)
# Out:
# /var/folders/18/9t4s6gxn2qb60_74h5w_ymmw0000gn/T/ipykernel_50154/1810520427.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['prices'].replace(14900.0, 4, inplace=True)

# %%
df['prices'] = df['prices'].replace(14900, 4)

# %%
filtered_df.head()
# Out:
#        order_id  user_id  order_number  orders_day_of_week  order_hour_placed  \
# 1576     912404       17            12                   2                 14
# 1638     603376       17            22                   6                 16
# 16522   3264360      135             2                   2                 21
# 16528    892534      135             3                   0                  8
# 53672    229704      342             8                   1                 19
#
#        days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 1576                      5.0       21553                  5          0
# 1638                      4.0       21553                  3          1
# 16522                    13.0       21553                  6          0
# 16528                    12.0       21553                  3          1
# 53672                    30.0       21553                  9          0
#
#                            product_name  aisle_id  department_id   prices  \
# 1576   Lowfat 2% Milkfat Cottage Cheese       108             16  14900.0
# 1638   Lowfat 2% Milkfat Cottage Cheese       108             16  14900.0
# 16522  Lowfat 2% Milkfat Cottage Cheese       108             16  14900.0
# 16528  Lowfat 2% Milkfat Cottage Cheese       108             16  14900.0
# 53672  Lowfat 2% Milkfat Cottage Cheese       108             16  14900.0
#
#       _merge  max_order      loyalty_flag    avg_price spending_flag  \
# 1576    both         40  Regular customer   108.648299  High Spender
# 1638    both         40  Regular customer   108.648299  High Spender
# 16522   both          4      New customer  1154.792308  High Spender
# 16528   both          4      New customer  1154.792308  High Spender
# 53672   both         16  Regular customer   114.426619  High Spender
#
#        med_days_prior         frequency_flag
# 1576              5.0      Frequent customer
# 1638              5.0      Frequent customer
# 16522            12.0       Regular customer
# 16528            12.0       Regular customer
# 53672            23.0  Non-frequent customer

# %%
filtered_df = df[df['prices'] == 14900]
print(filtered_df)
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, orders_day_of_week, order_hour_placed, days_since_prior_order, product_id, add_to_cart_order, reordered, product_name, aisle_id, department_id, prices, _merge, max_order, loyalty_flag, avg_price, spending_flag, med_days_prior, frequency_flag]
# Index: []

# %%
filtered_df.head()
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, orders_day_of_week, order_hour_placed, days_since_prior_order, product_id, add_to_cart_order, reordered, product_name, aisle_id, department_id, prices, _merge, max_order, loyalty_flag, avg_price, spending_flag, med_days_prior, frequency_flag]
# Index: []

# %%
mean_price = df['prices'].mean()
print(mean_price)
# Out:
# 7.790372752431982

# %%
# Identify Max value
max_price = df['prices'].max()
print(max_price)
# Out:
# 25.0

# %% [markdown]
# ### Exporting Data

# %%
df.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'combo_7_25_v2.pkl'))
