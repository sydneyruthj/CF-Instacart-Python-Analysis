# %% [markdown]
# ## Correcting Values and Updated DF
#
# ### Contents
# #### Importing Libraries
# #### Importing Data
# #### Correcting Incorrect Values
# #### Adding flags from Task 4.8
# #### Exporting Data

# %% [markdown]
# ### Importing Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### Importing Data

# %%
# Define pathway to relevant folder
path = r'/Users/sydneyjohnson/Documents/CF Data Analytics Course/07-2024 Instacart Basket Analysis'

# %%
# Import ords_prods_merged.pkl
df = pd.read_pickle(os.path.join(path, '02 Data','Prepared Data', 'combo_w_loyalty.pkl'))

# %% [markdown]
# ### Correcting Incorrect Values

# %%
# Fixing Price of Lowfat 2% Milfat Cottage Cheese
df['prices'] = df['prices'].replace(14900, 4)

# %%
# Fixing Price of 2% Reduced Fat Milk
df['prices'] = df['prices'].replace(99999, 3)

# %%
# Check new mean (should be 7.79)
mean_price = df['prices'].mean()
print(mean_price)
# Out:
# 7.790372752431982

# %%
# Identify Max value
max_price = df['prices'].max()
print(max_price)
# Out:
# 25.0

# %% [markdown]
# ### Adding Flags from Task 4.8

# %%
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_placed  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# 0                                     Soda        77              7     9.0
# 1  Organic Unsweetened Vanilla Almond Milk        91             16    12.5
# 2                      Original Beef Jerky        23             19     4.4
# 3               Aged White Cheddar Popcorn        23             19     4.7
# 4         XL Pick-A-Size Paper Towel Rolls        54             17     1.0
#
#   _merge  max_order  loyalty_flag
# 0   both         10  New customer
# 1   both         10  New customer
# 2   both         10  New customer
# 3   both         10  New customer
# 4   both         10  New customer

# %%
# Get basic statistics for 'prices' grouped by 'loyalty_flag'
df.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                     prices
#                       mean  min   max
# loyalty_flag
# Loyal customer    7.773079  1.0  25.0
# New customer      7.800474  1.0  25.0
# Regular customer  7.797602  1.0  25.0

# %%
# Create an avg_price column for each user
df['avg_price'] = df.groupby(['user_id'])['prices'].transform('mean')

# %%
# Check new 'avg_price' column
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_placed  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# 0                                     Soda        77              7     9.0
# 1  Organic Unsweetened Vanilla Almond Milk        91             16    12.5
# 2                      Original Beef Jerky        23             19     4.4
# 3               Aged White Cheddar Popcorn        23             19     4.7
# 4         XL Pick-A-Size Paper Towel Rolls        54             17     1.0
#
#   _merge  max_order  loyalty_flag  avg_price
# 0   both         10  New customer   6.367797
# 1   both         10  New customer   6.367797
# 2   both         10  New customer   6.367797
# 3   both         10  New customer   6.367797
# 4   both         10  New customer   6.367797

# %%
# Define 'spending_flag' perameters
df.loc[df['avg_price'] < 10, 'spending_flag'] = 'Low Spender'
df.loc[df['avg_price'] >= 10, 'spending_flag'] = 'High Spender'

# %%
# Check new column
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_placed  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# 0                                     Soda        77              7     9.0
# 1  Organic Unsweetened Vanilla Almond Milk        91             16    12.5
# 2                      Original Beef Jerky        23             19     4.4
# 3               Aged White Cheddar Popcorn        23             19     4.7
# 4         XL Pick-A-Size Paper Towel Rolls        54             17     1.0
#
#   _merge  max_order  loyalty_flag  avg_price spending_flag
# 0   both         10  New customer   6.367797   Low Spender
# 1   both         10  New customer   6.367797   Low Spender
# 2   both         10  New customer   6.367797   Low Spender
# 3   both         10  New customer   6.367797   Low Spender
# 4   both         10  New customer   6.367797   Low Spender

# %%
# Create a 'med_days_prior' column for each user
df['med_days_prior'] = df.groupby(['user_id'])['days_since_prior_order'].transform('median')

# %%
# Check new column
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_placed  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# 0                                     Soda        77              7     9.0
# 1  Organic Unsweetened Vanilla Almond Milk        91             16    12.5
# 2                      Original Beef Jerky        23             19     4.4
# 3               Aged White Cheddar Popcorn        23             19     4.7
# 4         XL Pick-A-Size Paper Towel Rolls        54             17     1.0
#
#   _merge  max_order  loyalty_flag  avg_price spending_flag  med_days_prior
# 0   both         10  New customer   6.367797   Low Spender            20.5
# 1   both         10  New customer   6.367797   Low Spender            20.5
# 2   both         10  New customer   6.367797   Low Spender            20.5
# 3   both         10  New customer   6.367797   Low Spender            20.5
# 4   both         10  New customer   6.367797   Low Spender            20.5

# %%
# Define perameters for 'frequency_flag'
df.loc[df['med_days_prior'] > 20, 'frequency_flag'] = 'Non-frequent customer'
df.loc[(df['med_days_prior'] > 10) & (df['med_days_prior'] <= 20), 'frequency_flag'] = 'Regular customer'
df.loc[df['med_days_prior'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
# Check value counts for new flag
df['frequency_flag'].value_counts(dropna = False)
# Out:
# frequency_flag
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_placed  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# 0                                     Soda        77              7     9.0
# 1  Organic Unsweetened Vanilla Almond Milk        91             16    12.5
# 2                      Original Beef Jerky        23             19     4.4
# 3               Aged White Cheddar Popcorn        23             19     4.7
# 4         XL Pick-A-Size Paper Towel Rolls        54             17     1.0
#
#   _merge  max_order  loyalty_flag  avg_price spending_flag  med_days_prior  \
# 0   both         10  New customer   6.367797   Low Spender            20.5
# 1   both         10  New customer   6.367797   Low Spender            20.5
# 2   both         10  New customer   6.367797   Low Spender            20.5
# 3   both         10  New customer   6.367797   Low Spender            20.5
# 4   both         10  New customer   6.367797   Low Spender            20.5
#
#           frequency_flag
# 0  Non-frequent customer
# 1  Non-frequent customer
# 2  Non-frequent customer
# 3  Non-frequent customer
# 4  Non-frequent customer

# %% [markdown]
# ### Exporting Data

# %%
# Export df to pickle
df.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'combo_7_25_Correct.pkl'))
